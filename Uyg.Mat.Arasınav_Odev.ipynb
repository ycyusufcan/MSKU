# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as sp
import math

# %% [markdown]
# ### Soru 1

# %% [markdown]
# ####  H: Hasta,  P: Pozitif,  S: Sağlam

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Soru 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 10
p = 0.75
x = np.arange(0, 11)

# %%
px = sp.comb(n,x) * p**x * (1 - p)**(n-x)
px
# Out:
# array([9.53674316e-07, 2.86102295e-05, 3.86238098e-04, 3.08990479e-03,
#        1.62220001e-02, 5.83992004e-02, 1.45998001e-01, 2.50282288e-01,
#        2.81567574e-01, 1.87711716e-01, 5.63135147e-02])

# %%
plt.stem(x, px)
plt.grid()

# %% [markdown]
# ### i)

# %%
px = sp.comb(n,6) * p**6 * (1 - p)**(n-6)
px
# Out:
# 0.1459980010986328

# %% [markdown]
# ### ii)

# %%
px_toplam1 = []
for x in range(9,11):
    px_toplam1.append(sp.comb(n,x) * p**x * (1 - p)**(n-x)) 
print(px_toplam1)
sum(px_toplam1)
# Out:
# [0.1877117156982422, 0.056313514709472656]
# 0.24402523040771484

# %% [markdown]
# ### iii)

# %%
px_toplam2 = []
for x in range(0,8):
    px_toplam2.append(sp.comb(n,x) * p**x * (1 - p)**(n-x)) 
print(px_toplam2)
sum(px_toplam2)
# Out:
# [9.5367431640625e-07, 2.86102294921875e-05, 0.00038623809814453125, 0.00308990478515625, 0.016222000122070312, 0.058399200439453125, 0.1459980010986328, 0.25028228759765625]
# 0.4744071960449219

# %% [markdown]
# ### soru 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 3
x = np.arange(1,n+1)
p = 0.9

# %%
x
# Out:
# array([1, 2, 3])

# %%
px = p * (1 - p)**(x-1)
px
# Out:
# array([0.9  , 0.09 , 0.009])

# %%
plt.stem(x, px)
plt.grid()

# %% [markdown]
# ### Soru 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Sorudaki 2 şekilden alttaki şekilde gösterilen sistem daha güvenilirdir.

# %% [markdown]
# ### Soru 6

# %%
import pandas as pd

# %%
N = 50000
atislar = np.random.randint(1, 7, size=N)
ucler = atislar == 3
uclerkum = ucler.cumsum()
atisrange = np.arange(1, N + 1)

# %%
#zarlar = [1,3,3,1,1,2,3]
#zar3 =   [0 1 1 0 0 0 1]
#zarcum = [0 1 2 2 2 2 3]
#ozamanakadarkiatis = [1 2 3 4 5 6 7]

# %%
plt.figure(figsize=(10,8))
plt.plot(uclerkum / atisrange, label='Deneysel Frekans')
#plt.semilogx()
plt.axhline(1/6, color='red', label='Teorik Deger')
plt.legend()

# %% [markdown]
# #### Monte Carlo Simülasyonunda olduğu gibi deneyi çok kez tekrarlarsak sonuç gerçek değer olan 1/6'ya o kadar yakınsayacaktır.
